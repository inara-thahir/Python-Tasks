# %%
name = "fathima Inara"
reg_no = "26JSOFT119"
department = "BCA"
semester = "1"
skills = "C++"
hobbies = "Reading, Watching movies"
dream_company = "TCS, Infosys"
github = "https://github.com/inara-thahir"
linkedin = "www.linkedin.com/in/inara-thahir-067a9742a"
career_goal = "cloud engineer"
print("=" * 40)
print("        MY DIGITAL IDENTITY")
print("=" * 40)
print(f"Name: {name}")
print(f"Registration Number: {reg_no}")
print(f"Department: {department}")
print(f"Semester: {semester}")
print(f"Skills: {skills}")
print(f"Hobbies: {hobbies}")
print(f"Dream Companies: {dream_company}")
print(f"GitHub: {github}")
print(f"LinkedIn: {linkedin}")
print(f"Career Goal: {career_goal}")
print("=" * 40)
# Out:
# ...
#         MY DIGITAL IDENTITY
# ...
# Name: fathima Inara
# Registration Number: 26JSOFT119
# Department: BCA
# Semester: 1
# Skills: C++
# Hobbies: Reading, Watching movies
# Dream Companies: TCS, Infosys
# GitHub: https://github.com/inara-thahir
# LinkedIn: www.linkedin.com/in/inara-thahir-067a9742a
# Career Goal: cloud engineer
# ...

# %% [markdown]
# ## My Digital Identity
#
# **Name:** fathima Inara
# **Registration Number:** 26JSOFT119
# **Department:** BCA
# **Semester:** 1
# **Skills:** C++
# **Hobbies:** Reading, Watching movies
# **Dream Companies:** TCS, Infosys
# **GitHub:** [https://github.com/inara-thahir](https://github.com/inara-thahir)
# **LinkedIn:** Redacted
